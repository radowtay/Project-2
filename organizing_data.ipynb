# %%
import pandas as pd

# %%
arrest_totals = "arrest_totals.csv"

# %%
arrests_df=pd.read_csv(arrest_totals)

# %%
arrests_df.tail()
# Out:
#      AGENCY_ID  OFFENSE_TYPE_ID UCR_AGENCY_NAME  \
# 607      19756               55          AUSTIN
# 608      19825               55          VERNON
# 609      19870               55         HOUSTON
# 610      19498               33            WACO
# 611      19752               33      SAN ANGELO
#
#                                  COUNTY_NAME OFFENSE_NAME  INCIDENT_COUNT  \
# 607                ['WILLIAMSON', ' TRAVIS']       Incest               1
# 608                            ['WILBARGER']       Incest               1
# 609  ['MONTGOMERY', ' FORT BEND', ' HARRIS']       Incest               1
# 610                             ['MCLENNAN']  Peeping Tom               2
# 611                            ['TOM GREEN']  Peeping Tom               1
#
#         COUNTY_CODE
# 607      [246, 227]
# 608           [244]
# 609  [170, 79, 101]
# 610           [155]
# 611           [226]

# %%
offense_df=arrests_df[["COUNTY_NAME","COUNTY_CODE","OFFENSE_TYPE_ID","OFFENSE_NAME","INCIDENT_COUNT"]]
offense_df.sort_values(by="COUNTY_NAME")
# Out:
#       COUNTY_NAME COUNTY_CODE  OFFENSE_TYPE_ID                   OFFENSE_NAME  \
# 0     ['ANDREWS']         [2]                3                 Statutory Rape
# 50    ['ANDREWS']         [2]               36                           Rape
# 238   ['ANDREWS']         [2]               56                       Fondling
# 51   ['ANGELINA']         [3]               36                           Rape
# 1     ['ARANSAS']         [4]                3                 Statutory Rape
# ..            ...         ...              ...                            ...
# 533      ['WISE']       [249]                4  Sexual Assault With An Object
# 490      ['WISE']       [249]               30                   Prostitution
# 448     ['YOUNG']       [252]                8   Pornography/Obscene Material
# 581     ['YOUNG']       [252]               43                         Sodomy
# 230    ['ZAVALA']       [254]               36                           Rape
#
#      INCIDENT_COUNT
# ...
