# %%
import pandas as pd
import numpy as np

# %%
arrest_totals = "../Extracts/arrest_totals.csv"

# %%
arrests_df=pd.read_csv(arrest_totals)

# %%
arrests_df.tail()
# Out:
#      AGENCY_ID  OFFENSE_TYPE_ID UCR_AGENCY_NAME  \
# 607      19756               55          AUSTIN
# 608      19825               55          VERNON
# 609      19870               55         HOUSTON
# 610      19498               33            WACO
# 611      19752               33      SAN ANGELO
#
#                                  COUNTY_NAME OFFENSE_NAME  INCIDENT_COUNT  \
# 607                ['WILLIAMSON', ' TRAVIS']       Incest               1
# 608                            ['WILBARGER']       Incest               1
# 609  ['MONTGOMERY', ' FORT BEND', ' HARRIS']       Incest               1
# 610                             ['MCLENNAN']  Peeping Tom               2
# 611                            ['TOM GREEN']  Peeping Tom               1
#
#         COUNTY_CODE
# 607      [246, 227]
# 608           [244]
# 609  [170, 79, 101]
# 610           [155]
# 611           [226]

# %%
offense_df=arrests_df[["COUNTY_CODE","OFFENSE_TYPE_ID","INCIDENT_COUNT"]]
offense_df
# Out:
#         COUNTY_CODE  OFFENSE_TYPE_ID  INCIDENT_COUNT
# 0               [2]                3               1
# 1               [4]                3               2
# 2              [14]                3               2
# 3              [14]                3               1
# 4              [21]                3               1
# ..              ...              ...             ...
# 607      [246, 227]               55               1
# 608           [244]               55               1
# 609  [170, 79, 101]               55               1
# 610           [155]               33               2
# 611           [226]               33               1
#
# [612 rows x 3 columns]

# %%
offense_df.to_csv("../Resources/offense_county.csv")
