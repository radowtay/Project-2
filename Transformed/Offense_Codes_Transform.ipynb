# %%
import pandas as pd

# %%
offence_types_raw = "../Resources/NIBRS_OFFENSE_TYPE.csv"

# %%
offence_cats_df = pd.read_csv(offence_types_raw)

# %%
offence_cats_df
# Out:
#     OFFENSE_TYPE_ID OFFENSE_CODE                                OFFENSE_NAME  \
# 0                58          23*                               Not Specified
# 1                 1          09C                        Justifiable Homicide
# 2                 2          26A     False Pretenses/Swindle/Confidence Game
# 3                 3          36B                              Statutory Rape
# 4                 4          11C               Sexual Assault With An Object
# ..              ...          ...                                         ...
# 81               68          26H                            Money Laundering
# 82               36          11A                                        Rape
# 83               50          23E  Theft From Coin-Operated Machine or Device
# 84               10          90D                 Driving Under the Influence
# 85               48          90Z                          All Other Offenses
#
# ...

# %%
offense_names_df = offence_cats_df[['OFFENSE_TYPE_ID','OFFENSE_NAME']]
offense_names_df
# Out:
#     OFFENSE_TYPE_ID                                OFFENSE_NAME
# 0                58                               Not Specified
# 1                 1                        Justifiable Homicide
# 2                 2     False Pretenses/Swindle/Confidence Game
# 3                 3                              Statutory Rape
# 4                 4               Sexual Assault With An Object
# ..              ...                                         ...
# 81               68                            Money Laundering
# 82               36                                        Rape
# 83               50  Theft From Coin-Operated Machine or Device
# 84               10                 Driving Under the Influence
# 85               48                          All Other Offenses
#
# [86 rows x 2 columns]

# %%
offense_names_df.to_csv('../Transformed/offense_code_names.csv')
